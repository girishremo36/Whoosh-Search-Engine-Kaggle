# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler,SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertConfig
from transformers import AdamW, BertForSequenceClassification, get_linear_schedule_with_warmup

# %%
from tqdm import tqdm, trange

# %%
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
import spacy
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import torch
from sklearn.feature_extraction.text import CountVectorizer
from Chapter01.dividing_into_sentences import read_text_file, preprocess_text, divide_into_sentences_nltk
from nltk.corpus import wordnet
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Star\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce 840M'

# %%
df_train = pd.read_csv("merged_train.csv", delimiter='\,', header=None,
names=['label','publication_number', 'cpc_code', 'sentence'])
df_train.shape
# Out:
# C:\Users\Star\AppData\Local\Temp\ipykernel_16924\1542940330.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_train = pd.read_csv("merged_train.csv", delimiter='\,', header=None,
# (1048575, 4)

# %%
pd.set_option('display.max_colwidth', None)
df_train.sample(10)
# Out:
#            label publication_number        cpc_code  \
# 231406    231406     US-11491030-B2     A61B17/1684
# 403453    403453   US-2013344081-A1       A61P25/00
# 218802    218802     US-11413939-B2       B60J1/006
# 663978    663978   US-2023022652-A1     H04L61/5007
# 970907    970907      US-7045252-B2        H01M6/06
# 267046    267046     US-11675567-B2       G06N3/047
# 1024440  1024440      US-7633872-B2  H04Q2213/13164
# 156931    156931     US-11031793-B2       H01M10/42
# 26228      26228     US-10183660-B2       B60W10/06
# 148940    148940     US-10978403-B2  H01L2224/29147
#
#                                                                                                                              sentence
# 231406                                                                                                             {for the shoulder}
# 403453                                                                                      Drugs for disorders of the nervous system
# 218802                               {characterised by fixation means such as clips  adhesive  etc. (incorporated in seal B60J10/70)}
# 663978                                                                                               Internet protocol [IP] addresses
# 970907                                                            Dry cells  i.e. cells wherein the electrolyte is rendered non-fluid
# 267046                                                                                           Probabilistic or stochastic networks
# 1024440                                                                                       Traffic (registration  measurement ...)
# 156931   Methods or arrangements for servicing or maintenance of secondary cells or secondary half-cells (H01M10/60 takes precedence)
# 26228                                                                                         including control of combustion engines
# 148940                                                                                           Copper [Cu] as principal constituent

# %%
sentences = df_train.sentence.values

# %%
sentences = ["[CLS] " + sentence + " [SEP]" for sentence in sentences]
labels = df_train.label.values

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]
print ("Tokenize the first sentence:")
print (tokenized_texts[10])
# Out:
# Tokenize the first sentence:
# ['[CLS]', '{', 'shaping', '}', '[SEP]']

# %%
print (tokenized_texts[9])
# Out:
# ['[CLS]', 'bea', '##d', 'characterized', 'by', 'the', 'radial', 'extent', 'of', 'apex', 'flip', '##per', 'or', 'cha', '##fer', 'into', 'tire', 'side', '##wall', '[SEP]']

# %%
MAX_LEN = 128

# %%
input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]

# %%
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long",truncating="post", padding="post")

# %%
print (input_ids)
# Out:
# [[  101  6512  1997 ...     0     0     0]
#  [  101  1063  2007 ...     0     0     0]
#  [  101  1063  2007 ...     0     0     0]
#  ...
#  [  101  3424 23585 ...     0     0     0]
#  [  101  1015  1016 ...     0     0     0]
#  [  101  3495  5799 ...     0     0     0]]

# %%
attention_masks = []

# %%
for seq in input_ids:
    seq_mask = [float(i>0) for i in seq]
    attention_masks.append(seq_mask)

# %%
train_inputs, validation_inputs, train_labels, validation_labels =train_test_split(input_ids, labels, random_state=2018, test_size=0.1)
train_masks, validation_masks, _, _ = train_test_split(attention_masks,input_ids,random_state=2018, test_size=0.1)

# %%
train_inputs = torch.tensor(train_inputs)
validation_inputs = torch.tensor(validation_inputs)
train_labels = torch.tensor(train_labels)
validation_labels = torch.tensor(validation_labels)
train_masks = torch.tensor(train_masks)
validation_masks = torch.tensor(validation_masks)

# %%
batch_size = 32

# %%
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# %%
validation_data = TensorDataset(validation_inputs, validation_masks,validation_labels)
validation_sampler = SequentialSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# %%
print (input_ids)
# Out:
# [[  101  6512  1997 ...     0     0     0]
#  [  101  1063  2007 ...     0     0     0]
#  [  101  1063  2007 ...     0     0     0]
#  ...
#  [  101  3424 23585 ...     0     0     0]
#  [  101  1015  1016 ...     0     0     0]
#  [  101  3495  5799 ...     0     0     0]]

# %%
try:
    import transformers
except:
    print("Installing transformers")
    # !pip -qq install transformers

# %%
from transformers import BertModel, BertConfig
configuration = BertConfig()

# %%
model = BertModel(configuration)

# %%
configuration = model.config
print(configuration)
# Out:
# BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.41.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",num_labels=2)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
print("Torch version:",torch.__version__)
# Out:
# Torch version: 2.2.2+cu118

# %%
print("Is CUDA enabled?",torch.cuda.is_available())
# Out:
# Is CUDA enabled? True

# %%
param_optimizer = list(model.named_parameters())
no_decay = ['bias', 'LayerNorm.weight']

# %%
optimizer_grouped_parameters = [
    {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay_rate': 0.1},
    {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay_rate': 0.0}]

# %%
optimizer = torch.optim.AdamW(optimizer_grouped_parameters,lr=2e-5)

# %%
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
t = []
train_loss_set = []

# %%
epochs = 4

# %%
df_test = pd.read_csv("merged_test.csv", delimiter='\,', header=None,
names=['label','publication_number', 'cpc_code', 'sentence'])
df_test.shape
# Out:
# C:\Users\Star\AppData\Local\Temp\ipykernel_16924\1185935696.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_test = pd.read_csv("merged_test.csv", delimiter='\,', header=None,
# (58, 4)

# %%
labels = df_test.label.values
sentences_list = df_test['sentence'].values.tolist()
sentences = df_test['sentence']
sentences
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {involving kinase}
# 1                                                                                                                                                                                                                                                                                                                                       Omics  e.g. proteomics  glycomics or lipidomics; Methods of analysis focusing on the entire complement of classes of biological molecules or subsets thereof  i.e. focusing on proteomes  glycomes or lipidomes
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {Methods of identifying protein-protein interactions in protein mixtures}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {Methods of protein analysis involving mass spectrometry}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                         ICT specially adapted for hybridisation; ICT specially adapted for gene or protein expression
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Gene or protein expression profiling; Expression-ratio estimation or normalisation
# 6                                                                                                                                                                                                                                                                                                                                                                                              ICT specially adapted for modelling or simulations in systems biology  e.g. gene-regulatory networks  protein interaction networks or metabolic networks
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {Discovery through centralising entities}
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                           for supporting data block transmission mechanisms (file transfer H04L67/06)
# 9                                                                                                                                                                                                                                                                                                                                                                                 for distributed storage of data in networks  e.g. transport arrangements for network file system [NFS]  storage area networks [SAN] or network attached storage [NAS]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Sunroofs (B60J7/047Â -Â B60J7/053 take precedence){e.g. sliding above the roof}
# 11                                                                                                                                                                                                                                                                                                                                                                                                                    sliding with final closing motion having vertical component to attain closed and sealed condition {  e.g. sliding under the roof}
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {Converting light into electric energy  e.g. by using photo-voltaic systems}
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Arrangements for holding or mounting articles  not otherwise provided for
# 14                                                                                                                                                                                                                                                                                                                                                                                                                         Sealing strips (sealing arrangements for vehicle windows  windscreens  non-fixed roofs  doors  or similar devices B60J10/00)
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {for protecting heat sensitive parts  e.g. electronic components}
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                              {using generators driven by a machine different from the vehicle motor}
# 17                                                                                                                                                                                                                                                                                                                                                characterised by the use of electrical cells or batteries (for propulsion puposes B60K1/04; supplying batteries to  or removing batteries from  vehicles B60S5/06; testing of charge state G01R31/36)
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {outside the vehicle}
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              {with visible part  e.g. flush mounted}
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {with adjustment by linear movement in their operational position}
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {for solar cells}
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                     Arrangements for cooling  heating  ventilating or temperature compensation (for photovoltaic devices H01L31/052)
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {characterised by the composition of the encapsulation material}
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Protective back sheets
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        for ICE-powered road vehicles
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           with light sensitive cells
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Mobile PV generator systems
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Supporting structures being movable or adjustable  e.g. for angle adjustment
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Frame structures
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Energy storage means  e.g. batteries  structurally associated with PV modules
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Photovoltaic [PV] energy
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Systems combining energy storage with energy generation of non-fossil origin
# 33                                                                                                                                                                                                                                                                                                                                                                                                                      Electromobility specific charging systems or methods for batteries  ultracapacitors  supercapacitors or double-layer capacitors
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                           Energy harvesting concepts as power supply for auxiliaries' energy consumption  e.g. photovoltaic sun-roof
# 35                                                                                                                                                                                                                                                                                                                                                 Emotion or mood input determined on the basis of sensed human body parameters such as pulse  heart rate or beat  temperature of skin  facial expressions  iris  voice pitch  brain activity patterns
# 36                                                                                                                                                                                                                                                                                                                                                                                                                            {Arrangements for interaction with the human body  e.g. for user immersion in virtual reality (blind teaching G09B21/00)}
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                               {for generating or manipulating the scene composition of objects  e.g. MPEG-4 objects}
# 38                                                                                                                      {involving operations for analysing video streams  e.g. detecting features or characteristics (television picture signal circuitry for scene change detection H04N5/147; filtering for image enhancement G06T5/00; methods or arrangements for recognising scenes G06V20/00; arrangements characterised by components specially adapted for monitoring  identification or recognition of video in broadcast systems H04H60/59)}
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {for generating different versions}
# 40                                                                                      {involving the geographical location of the client (retrieval from the Internet by querying based on geographical locations G06F16/9537; arrangements for identifying locations of receiving stations in broadcast systems H04H60/51; location of the user terminal in data switching networks H04L67/52; services making use of the location of users or terminals in wireless networks H04W4/02; locating users or terminals in wireless networks H04W64/00)}
# 41                                                                                                                                                                                                                              {being end-user preferences (retrieval of video data in a video database based on user preferences G06F16/739; arrangements for recognizing users' preferences H04H60/46; user profiles in network data switching protocols H04L67/306; processing of user preferences or user profiles in wireless networks H04W8/18)}
# 42                                                                                                                                                                                                                                                                                                                                                                                                                                                           {environmental sensors  e.g. for detecting temperature  luminosity  pressure  earthquakes}
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {sound input device  e.g. microphone}
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Cameras (H04N23/00 takes precedence)
# 45    {Detecting physical presence or behaviour of the user  e.g. using sensors to detect if the user is leaving the room or changes his face expression during a TV program (methods or arrangements for recognising human body or animal bodies or body parts G06V40/10; methods or arrangements for acquiring or recognising human faces  facial parts  facial sketches  facial expressions G06V40/16; methods or arrangements for recognising movements or behaviour G06V40/20; arrangements for identifying users in broadcast systems H04H60/45)}
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Control parameters  e.g. trick play commands  viewpoint selection
# 47                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {Buckets discharging overhead into a container mounted on the machine}
# 48                                                                                                                                                                                                                                                                                                                                                  Component parts of dredgers or soil-shifting machines  not restricted to one of the kinds covered by groups E02F3/00Â -Â E02F7/00 (laying-out or take-up devices for trailing electric cables B66C)
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {for moving on rails}
# 50                                                                                                                                                                                                                                                                                                                                                                               {Improving mounting or assembling  e.g. frame elements  disposition of all the components on the superstructures (for disposition of specific components  E02F9/0858)}
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           using gettering substances
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                                            {characterised by drive mechanism for valves or membrane index mechanism}
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {characterised by features of meter body or housing}
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {with symmetrical generally U-shaped clamps}
# 55                                                                                                                                                                                                                                                                                                                                                                                                                   {sensing of data fields affixed to objects or articles  e.g. coded labels (postal sorting B07C3/14  conveying articles B65G47/48)}
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                          of printed characters having additional code marks or containing code marks
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                with automatic carbide feed by valves
# Name: sentence, dtype: object

# %%
nlp = spacy.load("en_core_web_sm")
text = sentences[57]

#doc = nlp(sentences[:])
filtered_words = [token.text for token in nlp(sentences[1]) if not token.is_stop]
clean_text = ' '.join(filtered_words)
print("Original Text:", sentences[57])
print("Text after Stopword Removal:", clean_text)
# Out:
# Original Text: with automatic carbide feed by valves
# Text after Stopword Removal: Omics   e.g. proteomics   glycomics lipidomics ; Methods analysis focusing entire complement classes biological molecules subsets thereof   i.e. focusing proteomes   glycomes lipidomes

# %%
nlp = spacy.load("en_core_web_sm")
text = "There is a pen on the table"
doc = nlp(text)
filtered_words = [token.text for token in doc if not token.is_stop]
clean_text = ' '.join(filtered_words)
print("Original Text:", text)
print("Text after Stopword Removal:", clean_text)
# Out:
# Original Text: There is a pen on the table
# Text after Stopword Removal: pen table

# %%
pd.set_option('display.width', 1000)
cpc_words_df= pd.DataFrame(columns=['label', 'cpc_words'])
vectorizer = CountVectorizer(stop_words='english')
#X = vectorizer.fit_transform(sentences)
analyze = vectorizer.build_analyzer()
#print(vectorizer.get_feature_names_out(1))
for i in range(len(sentences)):
    row = [labels[i], analyze(sentences[i])]
#    print(i)
#    slno = labels[i]
#    word_list = analyze(sentences[i])
    cpc_words_df.loc[len(cpc_words_df)] = row
cpc_words_df = cpc_words_df.reset_index(drop=True)  
cpc_words_df
# Out:
#     label                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               cpc_words
# 0       0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [involving, kinase]
# 1       1                                                                                                                                                                                                                                                                                                                 [omics, proteomics, glycomics, lipidomics, methods, analysis, focusing, entire, complement, classes, biological, molecules, subsets, thereof, focusing, proteomes, glycomes, lipidomes]
# 2       2                                                                                                                                                                                                                                                                                                                                                                                                                               [methods, identifying, protein, protein, interactions, protein, mixtures]
# 3       3                                                                                                                                                                                                                                                                                                                                                                                                                                             [methods, protein, analysis, involving, mass, spectrometry]
# 4       4                                                                                                                                                                                                                                                                                                                                                                                                            [ict, specially, adapted, hybridisation, ict, specially, adapted, gene, protein, expression]
# 5       5                                                                                                                                                                                                                                                                                                                                                                                                                    [gene, protein, expression, profiling, expression, ratio, estimation, normalisation]
# 6       6                                                                                                                                                                                                                                                                                                                                                    [ict, specially, adapted, modelling, simulations, systems, biology, gene, regulatory, networks, protein, interaction, networks, metabolic, networks]
# 7       7                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [discovery, centralising, entities]
# 8       8                                                                                                                                                                                                                                                                                                                                                                                                                         [supporting, data, block, transmission, mechanisms, file, transfer, h04l67, 06]
# 9       9                                                                                                                                                                                                                                                                                                                                                      [distributed, storage, data, networks, transport, arrangements, network, file, nfs, storage, area, networks, san, network, attached, storage, nas]
# 10     10                                                                                                                                                                                                                                                                                                                                                                                                                                          [sunroofs, b60j7, 047â, b60j7, 053, precedence, sliding, roof]
# 11     11                                                                                                                                                                                                                                                                                                                                                                                        [sliding, final, closing, motion, having, vertical, component, attain, closed, sealed, condition, sliding, roof]
# 12     12                                                                                                                                                                                                                                                                                                                                                                                                                                   [converting, light, electric, energy, using, photo, voltaic, systems]
# 13     13                                                                                                                                                                                                                                                                                                                                                                                                                                                   [arrangements, holding, mounting, articles, provided]
# 14     14                                                                                                                                                                                                                                                                                                                                                                         [sealing, strips, sealing, arrangements, vehicle, windows, windscreens, non, fixed, roofs, doors, similar, devices, b60j10, 00]
# 15     15                                                                                                                                                                                                                                                                                                                                                                                                                                            [protecting, heat, sensitive, parts, electronic, components]
# 16     16                                                                                                                                                                                                                                                                                                                                                                                                                                         [using, generators, driven, machine, different, vehicle, motor]
# 17     17                                                                                                                                                                                                                                                                                                                  [characterised, use, electrical, cells, batteries, propulsion, puposes, b60k1, 04, supplying, batteries, removing, batteries, vehicles, b60s5, 06, testing, charge, state, g01r31, 36]
# 18     18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [outside, vehicle]
# 19     19                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [visible, flush, mounted]
# 20     20                                                                                                                                                                                                                                                                                                                                                                                                                                                   [adjustment, linear, movement, operational, position]
# 21     21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [solar, cells]
# 22     22                                                                                                                                                                                                                                                                                                                                                                                            [arrangements, cooling, heating, ventilating, temperature, compensation, photovoltaic, devices, h01l31, 052]
# 23     23                                                                                                                                                                                                                                                                                                                                                                                                                                                   [characterised, composition, encapsulation, material]
# 24     24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [protective, sheets]
# 25     25                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [ice, powered, road, vehicles]
# 26     26                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [light, sensitive, cells]
# 27     27                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [mobile, pv, generator, systems]
# 28     28                                                                                                                                                                                                                                                                                                                                                                                                                                        [supporting, structures, movable, adjustable, angle, adjustment]
# 29     29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [frame, structures]
# 30     30                                                                                                                                                                                                                                                                                                                                                                                                                              [energy, storage, means, batteries, structurally, associated, pv, modules]
# 31     31                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [photovoltaic, pv, energy]
# 32     32                                                                                                                                                                                                                                                                                                                                                                                                                          [systems, combining, energy, storage, energy, generation, non, fossil, origin]
# 33     33                                                                                                                                                                                                                                                                                                                                                                         [electromobility, specific, charging, systems, methods, batteries, ultracapacitors, supercapacitors, double, layer, capacitors]
# 34     34                                                                                                                                                                                                                                                                                                                                                                                                [energy, harvesting, concepts, power, supply, auxiliaries, energy, consumption, photovoltaic, sun, roof]
# 35     35                                                                                                                                                                                                                                                                                                             [emotion, mood, input, determined, basis, sensed, human, body, parameters, pulse, heart, rate, beat, temperature, skin, facial, expressions, iris, voice, pitch, brain, activity, patterns]
# 36     36                                                                                                                                                                                                                                                                                                                                                                                                [arrangements, interaction, human, body, user, immersion, virtual, reality, blind, teaching, g09b21, 00]
# 37     37                                                                                                                                                                                                                                                                                                                                                                                                                                  [generating, manipulating, scene, composition, objects, mpeg, objects]
# 38     38                                                                                   [involving, operations, analysing, video, streams, detecting, features, characteristics, television, picture, signal, circuitry, scene, change, detection, h04n5, 147, filtering, image, enhancement, g06t5, 00, methods, arrangements, recognising, scenes, g06v20, 00, arrangements, characterised, components, specially, adapted, monitoring, identification, recognition, video, broadcast, systems, h04h60, 59]
# 39     39                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [generating, different, versions]
# 40     40                                                                      [involving, geographical, location, client, retrieval, internet, querying, based, geographical, locations, g06f16, 9537, arrangements, identifying, locations, receiving, stations, broadcast, systems, h04h60, 51, location, user, terminal, data, switching, networks, h04l67, 52, services, making, use, location, users, terminals, wireless, networks, h04w4, 02, locating, users, terminals, wireless, networks, h04w64, 00]
# 41     41                                                                                                                                                                                     [end, user, preferences, retrieval, video, data, video, database, based, user, preferences, g06f16, 739, arrangements, recognizing, users, preferences, h04h60, 46, user, profiles, network, data, switching, protocols, h04l67, 306, processing, user, preferences, user, profiles, wireless, networks, h04w8, 18]
# 42     42                                                                                                                                                                                                                                                                                                                                                                                                                     [environmental, sensors, detecting, temperature, luminosity, pressure, earthquakes]
# 43     43                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [sound, input, device, microphone]
# 44     44                                                                                                                                                                                                                                                                                                                                                                                                                                                                [cameras, h04n23, 00, takes, precedence]
# 45     45  [detecting, physical, presence, behaviour, user, using, sensors, detect, user, leaving, room, changes, face, expression, tv, program, methods, arrangements, recognising, human, body, animal, bodies, body, parts, g06v40, 10, methods, arrangements, acquiring, recognising, human, faces, facial, parts, facial, sketches, facial, expressions, g06v40, 16, methods, arrangements, recognising, movements, behaviour, g06v40, 20, arrangements, identifying, users, broadcast, systems, h04h60, 45]
# 46     46                                                                                                                                                                                                                                                                                                                                                                                                                                      [control, parameters, trick, play, commands, viewpoint, selection]
# 47     47                                                                                                                                                                                                                                                                                                                                                                                                                                           [buckets, discharging, overhead, container, mounted, machine]
# 48     48                                                                                                                                                                                                                                                                                                                                    [component, parts, dredgers, soil, shifting, machines, restricted, kinds, covered, groups, e02f3, 00â, e02f7, 00, laying, devices, trailing, electric, cables, b66c]
# 49     49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [moving, rails]
# 50     50                                                                                                                                                                                                                                                                                                                                                            [improving, mounting, assembling, frame, elements, disposition, components, superstructures, disposition, specific, components, e02f9, 0858]
# 51     51                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [using, gettering, substances]
# 52     52                                                                                                                                                                                                                                                                                                                                                                                                                                   [characterised, drive, mechanism, valves, membrane, index, mechanism]
# 53     53                                                                                                                                                                                                                                                                                                                                                                                                                                                         [characterised, features, meter, body, housing]
# 54     54                                                                                                                                                                                                                                                                                                                                                                                                                                                                [symmetrical, generally, shaped, clamps]
# 55     55                                                                                                                                                                                                                                                                                                                                                                         [sensing, data, fields, affixed, objects, articles, coded, labels, postal, sorting, b07c3, 14, conveying, articles, b65g47, 48]
# 56     56                                                                                                                                                                                                                                                                                                                                                                                                                         [printed, characters, having, additional, code, marks, containing, code, marks]
# 57     57                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [automatic, carbide, feed, valves]

# %%
cpc_words_df.to_csv("cpc_words_converted.csv")

# %%
cpc_words_df['cpc_words'] = cpc_words_df['cpc_words'].apply(lambda x: list(pd.unique(x)))
cpc_words_df
# Out:
#     label                                                                                                                                                                                                                                                                                                                                                                                     cpc_words
# 0       0                                                                                                                                                                                                                                                                                                                                                                           [involving, kinase]
# 1       1                                                                                                                                                                                                                 [omics, proteomics, glycomics, lipidomics, methods, analysis, focusing, entire, complement, classes, biological, molecules, subsets, thereof, proteomes, glycomes, lipidomes]
# 2       2                                                                                                                                                                                                                                                                                                                                       [methods, identifying, protein, interactions, mixtures]
# 3       3                                                                                                                                                                                                                                                                                                                                   [methods, protein, analysis, involving, mass, spectrometry]
# 4       4                                                                                                                                                                                                                                                                                                                           [ict, specially, adapted, hybridisation, gene, protein, expression]
# 5       5                                                                                                                                                                                                                                                                                                                      [gene, protein, expression, profiling, ratio, estimation, normalisation]
# 6       6                                                                                                                                                                                                                                                              [ict, specially, adapted, modelling, simulations, systems, biology, gene, regulatory, networks, protein, interaction, metabolic]
# 7       7                                                                                                                                                                                                                                                                                                                                                           [discovery, centralising, entities]
# 8       8                                                                                                                                                                                                                                                                                                               [supporting, data, block, transmission, mechanisms, file, transfer, h04l67, 06]
# 9       9                                                                                                                                                                                                                                                                                 [distributed, storage, data, networks, transport, arrangements, network, file, nfs, area, san, attached, nas]
# 10     10                                                                                                                                                                                                                                                                                                                                       [sunroofs, b60j7, 047â, 053, precedence, sliding, roof]
# 11     11                                                                                                                                                                                                                                                                                       [sliding, final, closing, motion, having, vertical, component, attain, closed, sealed, condition, roof]
# 12     12                                                                                                                                                                                                                                                                                                                         [converting, light, electric, energy, using, photo, voltaic, systems]
# 13     13                                                                                                                                                                                                                                                                                                                                         [arrangements, holding, mounting, articles, provided]
# 14     14                                                                                                                                                                                                                                                                        [sealing, strips, arrangements, vehicle, windows, windscreens, non, fixed, roofs, doors, similar, devices, b60j10, 00]
# 15     15                                                                                                                                                                                                                                                                                                                                  [protecting, heat, sensitive, parts, electronic, components]
# 16     16                                                                                                                                                                                                                                                                                                                               [using, generators, driven, machine, different, vehicle, motor]
# 17     17                                                                                                                                                                                                                              [characterised, use, electrical, cells, batteries, propulsion, puposes, b60k1, 04, supplying, removing, vehicles, b60s5, 06, testing, charge, state, g01r31, 36]
# 18     18                                                                                                                                                                                                                                                                                                                                                                            [outside, vehicle]
# 19     19                                                                                                                                                                                                                                                                                                                                                                     [visible, flush, mounted]
# 20     20                                                                                                                                                                                                                                                                                                                                         [adjustment, linear, movement, operational, position]
# 21     21                                                                                                                                                                                                                                                                                                                                                                                [solar, cells]
# 22     22                                                                                                                                                                                                                                                                                  [arrangements, cooling, heating, ventilating, temperature, compensation, photovoltaic, devices, h01l31, 052]
# 23     23                                                                                                                                                                                                                                                                                                                                         [characterised, composition, encapsulation, material]
# 24     24                                                                                                                                                                                                                                                                                                                                                                          [protective, sheets]
# 25     25                                                                                                                                                                                                                                                                                                                                                                [ice, powered, road, vehicles]
# 26     26                                                                                                                                                                                                                                                                                                                                                                     [light, sensitive, cells]
# 27     27                                                                                                                                                                                                                                                                                                                                                              [mobile, pv, generator, systems]
# 28     28                                                                                                                                                                                                                                                                                                                              [supporting, structures, movable, adjustable, angle, adjustment]
# 29     29                                                                                                                                                                                                                                                                                                                                                                           [frame, structures]
# 30     30                                                                                                                                                                                                                                                                                                                    [energy, storage, means, batteries, structurally, associated, pv, modules]
# 31     31                                                                                                                                                                                                                                                                                                                                                                    [photovoltaic, pv, energy]
# 32     32                                                                                                                                                                                                                                                                                                                        [systems, combining, energy, storage, generation, non, fossil, origin]
# 33     33                                                                                                                                                                                                                                                               [electromobility, specific, charging, systems, methods, batteries, ultracapacitors, supercapacitors, double, layer, capacitors]
# 34     34                                                                                                                                                                                                                                                                                              [energy, harvesting, concepts, power, supply, auxiliaries, consumption, photovoltaic, sun, roof]
# 35     35                                                                                                                                                                                                   [emotion, mood, input, determined, basis, sensed, human, body, parameters, pulse, heart, rate, beat, temperature, skin, facial, expressions, iris, voice, pitch, brain, activity, patterns]
# 36     36                                                                                                                                                                                                                                                                                      [arrangements, interaction, human, body, user, immersion, virtual, reality, blind, teaching, g09b21, 00]
# 37     37                                                                                                                                                                                                                                                                                                                                 [generating, manipulating, scene, composition, objects, mpeg]
# 38     38  [involving, operations, analysing, video, streams, detecting, features, characteristics, television, picture, signal, circuitry, scene, change, detection, h04n5, 147, filtering, image, enhancement, g06t5, 00, methods, arrangements, recognising, scenes, g06v20, characterised, components, specially, adapted, monitoring, identification, recognition, broadcast, systems, h04h60, 59]
# 39     39                                                                                                                                                                                                                                                                                                                                                             [generating, different, versions]
# 40     40                                                         [involving, geographical, location, client, retrieval, internet, querying, based, locations, g06f16, 9537, arrangements, identifying, receiving, stations, broadcast, systems, h04h60, 51, user, terminal, data, switching, networks, h04l67, 52, services, making, use, users, terminals, wireless, h04w4, 02, locating, h04w64, 00]
# 41     41                                                                                                                                                                 [end, user, preferences, retrieval, video, data, database, based, g06f16, 739, arrangements, recognizing, users, h04h60, 46, profiles, network, switching, protocols, h04l67, 306, processing, wireless, networks, h04w8, 18]
# 42     42                                                                                                                                                                                                                                                                                                           [environmental, sensors, detecting, temperature, luminosity, pressure, earthquakes]
# 43     43                                                                                                                                                                                                                                                                                                                                                            [sound, input, device, microphone]
# 44     44                                                                                                                                                                                                                                                                                                                                                      [cameras, h04n23, 00, takes, precedence]
# 45     45                                                   [detecting, physical, presence, behaviour, user, using, sensors, detect, leaving, room, changes, face, expression, tv, program, methods, arrangements, recognising, human, body, animal, bodies, parts, g06v40, 10, acquiring, faces, facial, sketches, expressions, 16, movements, 20, identifying, users, broadcast, systems, h04h60, 45]
# 46     46                                                                                                                                                                                                                                                                                                                            [control, parameters, trick, play, commands, viewpoint, selection]
# 47     47                                                                                                                                                                                                                                                                                                                                 [buckets, discharging, overhead, container, mounted, machine]
# 48     48                                                                                                                                                                                                                          [component, parts, dredgers, soil, shifting, machines, restricted, kinds, covered, groups, e02f3, 00â, e02f7, 00, laying, devices, trailing, electric, cables, b66c]
# 49     49                                                                                                                                                                                                                                                                                                                                                                               [moving, rails]
# 50     50                                                                                                                                                                                                                                                                           [improving, mounting, assembling, frame, elements, disposition, components, superstructures, specific, e02f9, 0858]
# 51     51                                                                                                                                                                                                                                                                                                                                                                [using, gettering, substances]
# 52     52                                                                                                                                                                                                                                                                                                                                    [characterised, drive, mechanism, valves, membrane, index]
# 53     53                                                                                                                                                                                                                                                                                                                                               [characterised, features, meter, body, housing]
# 54     54                                                                                                                                                                                                                                                                                                                                                      [symmetrical, generally, shaped, clamps]
# 55     55                                                                                                                                                                                                                                                                         [sensing, data, fields, affixed, objects, articles, coded, labels, postal, sorting, b07c3, 14, conveying, b65g47, 48]
# 56     56                                                                                                                                                                                                                                                                                                                            [printed, characters, having, additional, code, marks, containing]
# 57     57                                                                                                                                                                                                                                                                                                                                                            [automatic, carbide, feed, valves]

# %%
cpc_words_df.to_csv("cpc_words_test.csv")

# %%
import pandas as pd
df_train_null = pd.read_csv("temp1.csv", delimiter=',',  header=None, names=['label','cpc_desc_unique'], encoding='latin1')
df_train_null.shape
# Out:
# (44500, 2)

# %%
df_train_null
# Out:
#        label                                                                            cpc_desc_unique
# 0          0                                                                 ribs, grooves, arrangement
# 1          1                                      edges, bead, turn, ply, belt, extending, core, folded
# 2          2            flange, position, rim, protectors, bead, located, outside, extensions, radially
# 3          3                                    shaped, sidewall, crescent, comprising, inserts, rubber
# 4          4                                                       tyre, constructions, parts, provided
# ...      ...                                                                                        ...
# 44495  44495                                                                                      pumps
# 44496  44496                                             g01n30, takes, precedence, 36, pressure, speed
# 44497  44497                                                                           moving, linearly
# 44498  44498  flow, 2625, 2617, b67c3, precedence, 2637, control, devices, using, f16k, general, valves
# 44499  44499                          outlet, flow, valve, nozzle, smoothing, bodies, profiled, filling
#
# [44500 rows x 2 columns]

# %%
pd.set_option('display.max_colwidth', None)
cpc_words_df[3595:3599]
# Out:
# Empty DataFrame
# Columns: [label, cpc_words]
# Index: []

# %%
cpc_words_df.to_csv("cpc_words_unique.csv")

# %%
del cpc_words_df['label']

# %%
cpc_words_df[3595:3599]
# Out:
# Empty DataFrame
# Columns: [cpc_words]
# Index: []

# %%
import pandas as pd
df_test_null = pd.read_csv("cpc_words_test.csv", delimiter=',',  header=None, names=['label','cpc_desc_unique'], encoding='latin1')
df_test_null
# Out:
#       label                                                                                                                                                                                                                                                                                                                                                                                                                                                           cpc_desc_unique
# NaN   label                                                                                                                                                                                                                                                                                                                                                                                                                                                                 cpc_words
# 0.0       0                                                                                                                                                                                                                                                                                                                                                                                                                                                   ['involving', 'kinase']
# 1.0       1                                                                                                                                                                                                                                                           ['omics', 'proteomics', 'glycomics', 'lipidomics', 'methods', 'analysis', 'focusing', 'entire', 'complement', 'classes', 'biological', 'molecules', 'subsets', 'thereof', 'proteomes', 'glycomes', 'lipidomes']
# 2.0       2                                                                                                                                                                                                                                                                                                                                                                                                         ['methods', 'identifying', 'protein', 'interactions', 'mixtures']
# 3.0       3                                                                                                                                                                                                                                                                                                                                                                                                   ['methods', 'protein', 'analysis', 'involving', 'mass', 'spectrometry']
# 4.0       4                                                                                                                                                                                                                                                                                                                                                                                         ['ict', 'specially', 'adapted', 'hybridisation', 'gene', 'protein', 'expression']
# 5.0       5                                                                                                                                                                                                                                                                                                                                                                                    ['gene', 'protein', 'expression', 'profiling', 'ratio', 'estimation', 'normalisation']
# 6.0       6                                                                                                                                                                                                                                                                                                                ['ict', 'specially', 'adapted', 'modelling', 'simulations', 'systems', 'biology', 'gene', 'regulatory', 'networks', 'protein', 'interaction', 'metabolic']
# 7.0       7                                                                                                                                                                                                                                                                                                                                                                                                                                 ['discovery', 'centralising', 'entities']
# 8.0       8                                                                                                                                                                                                                                                                                                                                                                         ['supporting', 'data', 'block', 'transmission', 'mechanisms', 'file', 'transfer', 'h04l67', '06']
# 9.0       9                                                                                                                                                                                                                                                                                                                                   ['distributed', 'storage', 'data', 'networks', 'transport', 'arrangements', 'network', 'file', 'nfs', 'area', 'san', 'attached', 'nas']
# 10.0     10                                                                                                                                                                                                                                                                                                                                                                                                    ['sunroofs', 'b60j7', '047Ã¢', '053', 'precedence', 'sliding', 'roof']
# 11.0     11                                                                                                                                                                                                                                                                                                                                           ['sliding', 'final', 'closing', 'motion', 'having', 'vertical', 'component', 'attain', 'closed', 'sealed', 'condition', 'roof']
# 12.0     12                                                                                                                                                                                                                                                                                                                                                                                     ['converting', 'light', 'electric', 'energy', 'using', 'photo', 'voltaic', 'systems']
# 13.0     13                                                                                                                                                                                                                                                                                                                                                                                                           ['arrangements', 'holding', 'mounting', 'articles', 'provided']
# 14.0     14                                                                                                                                                                                                                                                                                                                        ['sealing', 'strips', 'arrangements', 'vehicle', 'windows', 'windscreens', 'non', 'fixed', 'roofs', 'doors', 'similar', 'devices', 'b60j10', '00']
# 15.0     15                                                                                                                                                                                                                                                                                                                                                                                                  ['protecting', 'heat', 'sensitive', 'parts', 'electronic', 'components']
# 16.0     16                                                                                                                                                                                                                                                                                                                                                                                             ['using', 'generators', 'driven', 'machine', 'different', 'vehicle', 'motor']
# 17.0     17                                                                                                                                                                                                                                                                    ['characterised', 'use', 'electrical', 'cells', 'batteries', 'propulsion', 'puposes', 'b60k1', '04', 'supplying', 'removing', 'vehicles', 'b60s5', '06', 'testing', 'charge', 'state', 'g01r31', '36']
# 18.0     18                                                                                                                                                                                                                                                                                                                                                                                                                                                    ['outside', 'vehicle']
# 19.0     19                                                                                                                                                                                                                                                                                                                                                                                                                                           ['visible', 'flush', 'mounted']
# 20.0     20                                                                                                                                                                                                                                                                                                                                                                                                           ['adjustment', 'linear', 'movement', 'operational', 'position']
# 21.0     21                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['solar', 'cells']
# 22.0     22                                                                                                                                                                                                                                                                                                                                          ['arrangements', 'cooling', 'heating', 'ventilating', 'temperature', 'compensation', 'photovoltaic', 'devices', 'h01l31', '052']
# 23.0     23                                                                                                                                                                                                                                                                                                                                                                                                             ['characterised', 'composition', 'encapsulation', 'material']
# 24.0     24                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['protective', 'sheets']
# 25.0     25                                                                                                                                                                                                                                                                                                                                                                                                                                    ['ice', 'powered', 'road', 'vehicles']
# 26.0     26                                                                                                                                                                                                                                                                                                                                                                                                                                           ['light', 'sensitive', 'cells']
# 27.0     27                                                                                                                                                                                                                                                                                                                                                                                                                                  ['mobile', 'pv', 'generator', 'systems']
# 28.0     28                                                                                                                                                                                                                                                                                                                                                                                              ['supporting', 'structures', 'movable', 'adjustable', 'angle', 'adjustment']
# 29.0     29                                                                                                                                                                                                                                                                                                                                                                                                                                                   ['frame', 'structures']
# 30.0     30                                                                                                                                                                                                                                                                                                                                                                                ['energy', 'storage', 'means', 'batteries', 'structurally', 'associated', 'pv', 'modules']
# 31.0     31                                                                                                                                                                                                                                                                                                                                                                                                                                          ['photovoltaic', 'pv', 'energy']
# 32.0     32                                                                                                                                                                                                                                                                                                                                                                                    ['systems', 'combining', 'energy', 'storage', 'generation', 'non', 'fossil', 'origin']
# 33.0     33                                                                                                                                                                                                                                                                                                                     ['electromobility', 'specific', 'charging', 'systems', 'methods', 'batteries', 'ultracapacitors', 'supercapacitors', 'double', 'layer', 'capacitors']
# 34.0     34                                                                                                                                                                                                                                                                                                                                                      ['energy', 'harvesting', 'concepts', 'power', 'supply', 'auxiliaries', 'consumption', 'photovoltaic', 'sun', 'roof']
# 35.0     35                                                                                                                                                                                                                                 ['emotion', 'mood', 'input', 'determined', 'basis', 'sensed', 'human', 'body', 'parameters', 'pulse', 'heart', 'rate', 'beat', 'temperature', 'skin', 'facial', 'expressions', 'iris', 'voice', 'pitch', 'brain', 'activity', 'patterns']
# 36.0     36                                                                                                                                                                                                                                                                                                                                          ['arrangements', 'interaction', 'human', 'body', 'user', 'immersion', 'virtual', 'reality', 'blind', 'teaching', 'g09b21', '00']
# 37.0     37                                                                                                                                                                                                                                                                                                                                                                                                 ['generating', 'manipulating', 'scene', 'composition', 'objects', 'mpeg']
# 38.0     38  ['involving', 'operations', 'analysing', 'video', 'streams', 'detecting', 'features', 'characteristics', 'television', 'picture', 'signal', 'circuitry', 'scene', 'change', 'detection', 'h04n5', '147', 'filtering', 'image', 'enhancement', 'g06t5', '00', 'methods', 'arrangements', 'recognising', 'scenes', 'g06v20', 'characterised', 'components', 'specially', 'adapted', 'monitoring', 'identification', 'recognition', 'broadcast', 'systems', 'h04h60', '59']
# 39.0     39                                                                                                                                                                                                                                                                                                                                                                                                                                   ['generating', 'different', 'versions']
# 40.0     40                                                           ['involving', 'geographical', 'location', 'client', 'retrieval', 'internet', 'querying', 'based', 'locations', 'g06f16', '9537', 'arrangements', 'identifying', 'receiving', 'stations', 'broadcast', 'systems', 'h04h60', '51', 'user', 'terminal', 'data', 'switching', 'networks', 'h04l67', '52', 'services', 'making', 'use', 'users', 'terminals', 'wireless', 'h04w4', '02', 'locating', 'h04w64', '00']
# 41.0     41                                                                                                                                                                                         ['end', 'user', 'preferences', 'retrieval', 'video', 'data', 'database', 'based', 'g06f16', '739', 'arrangements', 'recognizing', 'users', 'h04h60', '46', 'profiles', 'network', 'switching', 'protocols', 'h04l67', '306', 'processing', 'wireless', 'networks', 'h04w8', '18']
# 42.0     42                                                                                                                                                                                                                                                                                                                                                                         ['environmental', 'sensors', 'detecting', 'temperature', 'luminosity', 'pressure', 'earthquakes']
# 43.0     43                                                                                                                                                                                                                                                                                                                                                                                                                                ['sound', 'input', 'device', 'microphone']
# 44.0     44                                                                                                                                                                                                                                                                                                                                                                                                                        ['cameras', 'h04n23', '00', 'takes', 'precedence']
# 45.0     45                                                 ['detecting', 'physical', 'presence', 'behaviour', 'user', 'using', 'sensors', 'detect', 'leaving', 'room', 'changes', 'face', 'expression', 'tv', 'program', 'methods', 'arrangements', 'recognising', 'human', 'body', 'animal', 'bodies', 'parts', 'g06v40', '10', 'acquiring', 'faces', 'facial', 'sketches', 'expressions', '16', 'movements', '20', 'identifying', 'users', 'broadcast', 'systems', 'h04h60', '45']
# 46.0     46                                                                                                                                                                                                                                                                                                                                                                                          ['control', 'parameters', 'trick', 'play', 'commands', 'viewpoint', 'selection']
# 47.0     47                                                                                                                                                                                                                                                                                                                                                                                                 ['buckets', 'discharging', 'overhead', 'container', 'mounted', 'machine']
# 48.0     48                                                                                                                                                                                                                                                             ['component', 'parts', 'dredgers', 'soil', 'shifting', 'machines', 'restricted', 'kinds', 'covered', 'groups', 'e02f3', '00Ã¢', 'e02f7', '00', 'laying', 'devices', 'trailing', 'electric', 'cables', 'b66c']
# 49.0     49                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['moving', 'rails']
# 50.0     50                                                                                                                                                                                                                                                                                                                                 ['improving', 'mounting', 'assembling', 'frame', 'elements', 'disposition', 'components', 'superstructures', 'specific', 'e02f9', '0858']
# 51.0     51                                                                                                                                                                                                                                                                                                                                                                                                                                      ['using', 'gettering', 'substances']
# 52.0     52                                                                                                                                                                                                                                                                                                                                                                                                    ['characterised', 'drive', 'mechanism', 'valves', 'membrane', 'index']
# 53.0     53                                                                                                                                                                                                                                                                                                                                                                                                                 ['characterised', 'features', 'meter', 'body', 'housing']
# 54.0     54                                                                                                                                                                                                                                                                                                                                                                                                                          ['symmetrical', 'generally', 'shaped', 'clamps']
# 55.0     55                                                                                                                                                                                                                                                                                                                       ['sensing', 'data', 'fields', 'affixed', 'objects', 'articles', 'coded', 'labels', 'postal', 'sorting', 'b07c3', '14', 'conveying', 'b65g47', '48']
# 56.0     56                                                                                                                                                                                                                                                                                                                                                                                          ['printed', 'characters', 'having', 'additional', 'code', 'marks', 'containing']
# 57.0     57                                                                                                                                                                                                                                                                                                                                                                                                                                ['automatic', 'carbide', 'feed', 'valves']

# %%
import pandas as pd
df_test_null = pd.read_csv("raw_test.csv", delimiter=',',  header=None, names=['label','cpc_desc_unique'], encoding='latin1')
df_test_null.shape
# Out:
# (58, 2)

# %%
import itertools
from itertools import groupby
import re

def is_alpha(word):
    return bool(re.match('^[a-zA-Z]+$', word))
corrected_df = pd.DataFrame(columns=['label', 'cpc_desc'])
new_list= df_test_null['cpc_desc_unique']
filtered_lists = []
dfs_to_concat = []
for i in range(len(new_list)):
    test_list = new_list[i]  # Assuming new_list is a list of strings
    words = test_list.split(', ')  # Split the string into words using comma as the delimiter
    res = [word for word in words if is_alpha(word)]  # Filter out non-alphabetic words
#    corrected_df = corrected_df.append({'label' :i, 'cpc_desc': res }, ignore_index=True)

    filtered_lists.append(res)
for i, res in enumerate(filtered_lists):
    df_row = pd.DataFrame({'label': [i], 'cpc_desc': [res]})
    corrected_df=pd.concat([corrected_df,df_row])
#    corrected_df = corrected_df.append({'label' :i, 'cpc_desc': res }, ignore_index=True)
    print(i, res)
corrected_df
# Out:
# 0 ['involving', 'kinase']
# 1 ['omics', 'proteomics', 'glycomics', 'lipidomics', 'methods', 'analysis', 'focusing', 'entire', 'complement', 'classes', 'biological', 'molecules', 'subsets', 'thereof', 'proteomes', 'glycomes', 'lipidomes']
# 2 ['methods', 'identifying', 'protein', 'interactions', 'mixtures']
# 3 ['methods', 'protein', 'analysis', 'involving', 'mass', 'spectrometry']
# 4 ['ict', 'specially', 'adapted', 'hybridisation', 'gene', 'protein', 'expression']
# 5 ['gene', 'protein', 'expression', 'profiling', 'ratio', 'estimation', 'normalisation']
# 6 ['ict', 'specially', 'adapted', 'modelling', 'simulations', 'systems', 'biology', 'gene', 'regulatory', 'networks', 'protein', 'interaction', 'metabolic']
# 7 ['discovery', 'centralising', 'entities']
# 8 ['supporting', 'data', 'block', 'transmission', 'mechanisms', 'file', 'transfer']
# 9 ['distributed', 'storage', 'data', 'networks', 'transport', 'arrangements', 'network', 'file', 'nfs', 'area', 'san', 'attached', 'nas']
# 10 ['sunroofs', 'precedence', 'sliding', 'roof']
# 11 ['sliding', 'final', 'closing', 'motion', 'having', 'vertical', 'component', 'attain', 'closed', 'sealed', 'condition', 'roof']
# 12 ['converting', 'light', 'electric', 'energy', 'using', 'photo', 'voltaic', 'systems']
# 13 ['arrangements', 'holding', 'mounting', 'articles', 'provided']
# 14 ['sealing', 'strips', 'arrangements', 'vehicle', 'windows', 'windscreens', 'non', 'fixed', 'roofs', 'doors', 'similar', 'devices']
# 15 ['protecting', 'heat', 'sensitive', 'parts', 'electronic', 'components']
# 16 ['using', 'generators', 'driven', 'machine', 'different', 'vehicle', 'motor']
# 17 ['characterised', 'use', 'electrical', 'cells', 'batteries', 'propulsion', 'puposes', 'supplying', 'removing', 'vehicles', 'testing', 'charge', 'state']
# 18 ['outside', 'vehicle']
# 19 ['visible', 'flush', 'mounted']
# 20 ['adjustment', 'linear', 'movement', 'operational', 'position']
# 21 ['solar', 'cells']
# 22 ['arrangements', 'cooling', 'heating', 'ventilating', 'temperature', 'compensation', 'photovoltaic', 'devices']
# 23 ['characterised', 'composition', 'encapsulation', 'material']
# 24 ['protective', 'sheets']
# 25 ['ice', 'powered', 'road', 'vehicles']
# 26 ['light', 'sensitive', 'cells']
# 27 ['mobile', 'pv', 'generator', 'systems']
# 28 ['supporting', 'structures', 'movable', 'adjustable', 'angle', 'adjustment']
# 29 ['frame', 'structures']
# 30 ['energy', 'storage', 'means', 'batteries', 'structurally', 'associated', 'pv', 'modules']
# 31 ['photovoltaic', 'pv', 'energy']
# 32 ['systems', 'combining', 'energy', 'storage', 'generation', 'non', 'fossil', 'origin']
# 33 ['electromobility', 'specific', 'charging', 'systems', 'methods', 'batteries', 'ultracapacitors', 'supercapacitors', 'double', 'layer', 'capacitors']
# 34 ['energy', 'harvesting', 'concepts', 'power', 'supply', 'auxiliaries', 'consumption', 'photovoltaic', 'sun', 'roof']
# 35 ['emotion', 'mood', 'input', 'determined', 'basis', 'sensed', 'human', 'body', 'parameters', 'pulse', 'heart', 'rate', 'beat', 'temperature', 'skin', 'facial', 'expressions', 'iris', 'voice', 'pitch', 'brain', 'activity', 'patterns']
# 36 ['arrangements', 'interaction', 'human', 'body', 'user', 'immersion', 'virtual', 'reality', 'blind', 'teaching']
# 37 ['generating', 'manipulating', 'scene', 'composition', 'objects', 'mpeg']
# 38 ['involving', 'operations', 'analysing', 'video', 'streams', 'detecting', 'features', 'characteristics', 'television', 'picture', 'signal', 'circuitry', 'scene', 'change', 'detection', 'filtering', 'image', 'enhancement', 'methods', 'arrangements', 'recognising', 'scenes', 'characterised', 'components', 'specially', 'adapted', 'monitoring', 'identification', 'recognition', 'broadcast', 'systems']
# 39 ['generating', 'different', 'versions']
# 40 ['involving', 'geographical', 'location', 'client', 'retrieval', 'internet', 'querying', 'based', 'locations', 'arrangements', 'identifying', 'receiving', 'stations', 'broadcast', 'systems', 'user', 'terminal', 'data', 'switching', 'networks', 'services', 'making', 'use', 'users', 'terminals', 'wireless', 'locating']
# 41 ['end', 'user', 'preferences', 'retrieval', 'video', 'data', 'database', 'based', 'arrangements', 'recognizing', 'users', 'profiles', 'network', 'switching', 'protocols', 'processing', 'wireless', 'networks']
# 42 ['environmental', 'sensors', 'detecting', 'temperature', 'luminosity', 'pressure', 'earthquakes']
# 43 ['sound', 'input', 'device', 'microphone']
# 44 ['cameras', 'takes', 'precedence']
# 45 ['detecting', 'physical', 'presence', 'behaviour', 'user', 'using', 'sensors', 'detect', 'leaving', 'room', 'changes', 'face', 'expression', 'tv', 'program', 'methods', 'arrangements', 'recognising', 'human', 'body', 'animal', 'bodies', 'parts', 'acquiring', 'faces', 'facial', 'sketches', 'expressions', 'movements', 'identifying', 'users', 'broadcast', 'systems']
# 46 ['control', 'parameters', 'trick', 'play', 'commands', 'viewpoint', 'selection']
# 47 ['buckets', 'discharging', 'overhead', 'container', 'mounted', 'machine']
# 48 ['component', 'parts', 'dredgers', 'soil', 'shifting', 'machines', 'restricted', 'kinds', 'covered', 'groups', 'laying', 'devices', 'trailing', 'electric', 'cables']
# 49 ['moving', 'rails']
# 50 ['improving', 'mounting', 'assembling', 'frame', 'elements', 'disposition', 'components', 'superstructures', 'specific']
# 51 ['using', 'gettering', 'substances']
# 52 ['characterised', 'drive', 'mechanism', 'valves', 'membrane', 'index']
# 53 ['characterised', 'features', 'meter', 'body', 'housing']
# 54 ['symmetrical', 'generally', 'shaped', 'clamps']
# 55 ['sensing', 'data', 'fields', 'affixed', 'objects', 'articles', 'coded', 'labels', 'postal', 'sorting', 'conveying']
# 56 ['printed', 'characters', 'having', 'additional', 'code', 'marks', 'containing']
# 57 ['automatic', 'carbide', 'feed', 'valves']
#   label                                                                                                                                                                                                                                                                                                                                           cpc_desc
# 0     0                                                                                                                                                                                                                                                                                                                                [involving, kinase]
# 0     1                                                                                                                                                                      [omics, proteomics, glycomics, lipidomics, methods, analysis, focusing, entire, complement, classes, biological, molecules, subsets, thereof, proteomes, glycomes, lipidomes]
# 0     2                                                                                                                                                                                                                                                                                            [methods, identifying, protein, interactions, mixtures]
# 0     3                                                                                                                                                                                                                                                                                        [methods, protein, analysis, involving, mass, spectrometry]
# 0     4                                                                                                                                                                                                                                                                                [ict, specially, adapted, hybridisation, gene, protein, expression]
# 0     5                                                                                                                                                                                                                                                                           [gene, protein, expression, profiling, ratio, estimation, normalisation]
# 0     6                                                                                                                                                                                                                   [ict, specially, adapted, modelling, simulations, systems, biology, gene, regulatory, networks, protein, interaction, metabolic]
# 0     7                                                                                                                                                                                                                                                                                                                [discovery, centralising, entities]
# 0     8                                                                                                                                                                                                                                                                                [supporting, data, block, transmission, mechanisms, file, transfer]
# 0     9                                                                                                                                                                                                                                      [distributed, storage, data, networks, transport, arrangements, network, file, nfs, area, san, attached, nas]
# 0    10                                                                                                                                                                                                                                                                                                              [sunroofs, precedence, sliding, roof]
# 0    11                                                                                                                                                                                                                                            [sliding, final, closing, motion, having, vertical, component, attain, closed, sealed, condition, roof]
# 0    12                                                                                                                                                                                                                                                                              [converting, light, electric, energy, using, photo, voltaic, systems]
# 0    13                                                                                                                                                                                                                                                                                              [arrangements, holding, mounting, articles, provided]
# 0    14                                                                                                                                                                                                                                         [sealing, strips, arrangements, vehicle, windows, windscreens, non, fixed, roofs, doors, similar, devices]
# 0    15                                                                                                                                                                                                                                                                                       [protecting, heat, sensitive, parts, electronic, components]
# 0    16                                                                                                                                                                                                                                                                                    [using, generators, driven, machine, different, vehicle, motor]
# 0    17                                                                                                                                                                                                                     [characterised, use, electrical, cells, batteries, propulsion, puposes, supplying, removing, vehicles, testing, charge, state]
# 0    18                                                                                                                                                                                                                                                                                                                                 [outside, vehicle]
# 0    19                                                                                                                                                                                                                                                                                                                          [visible, flush, mounted]
# 0    20                                                                                                                                                                                                                                                                                              [adjustment, linear, movement, operational, position]
# 0    21                                                                                                                                                                                                                                                                                                                                     [solar, cells]
# 0    22                                                                                                                                                                                                                                                    [arrangements, cooling, heating, ventilating, temperature, compensation, photovoltaic, devices]
# 0    23                                                                                                                                                                                                                                                                                              [characterised, composition, encapsulation, material]
# 0    24                                                                                                                                                                                                                                                                                                                               [protective, sheets]
# 0    25                                                                                                                                                                                                                                                                                                                     [ice, powered, road, vehicles]
# 0    26                                                                                                                                                                                                                                                                                                                          [light, sensitive, cells]
# 0    27                                                                                                                                                                                                                                                                                                                   [mobile, pv, generator, systems]
# 0    28                                                                                                                                                                                                                                                                                   [supporting, structures, movable, adjustable, angle, adjustment]
# 0    29                                                                                                                                                                                                                                                                                                                                [frame, structures]
# 0    30                                                                                                                                                                                                                                                                         [energy, storage, means, batteries, structurally, associated, pv, modules]
# 0    31                                                                                                                                                                                                                                                                                                                         [photovoltaic, pv, energy]
# 0    32                                                                                                                                                                                                                                                                             [systems, combining, energy, storage, generation, non, fossil, origin]
# 0    33                                                                                                                                                                                                                    [electromobility, specific, charging, systems, methods, batteries, ultracapacitors, supercapacitors, double, layer, capacitors]
# 0    34                                                                                                                                                                                                                                                   [energy, harvesting, concepts, power, supply, auxiliaries, consumption, photovoltaic, sun, roof]
# 0    35                                                                                                                                                        [emotion, mood, input, determined, basis, sensed, human, body, parameters, pulse, heart, rate, beat, temperature, skin, facial, expressions, iris, voice, pitch, brain, activity, patterns]
# 0    36                                                                                                                                                                                                                                                       [arrangements, interaction, human, body, user, immersion, virtual, reality, blind, teaching]
# 0    37                                                                                                                                                                                                                                                                                      [generating, manipulating, scene, composition, objects, mpeg]
# 0    38  [involving, operations, analysing, video, streams, detecting, features, characteristics, television, picture, signal, circuitry, scene, change, detection, filtering, image, enhancement, methods, arrangements, recognising, scenes, characterised, components, specially, adapted, monitoring, identification, recognition, broadcast, systems]
# 0    39                                                                                                                                                                                                                                                                                                                  [generating, different, versions]
# 0    40                                                                           [involving, geographical, location, client, retrieval, internet, querying, based, locations, arrangements, identifying, receiving, stations, broadcast, systems, user, terminal, data, switching, networks, services, making, use, users, terminals, wireless, locating]
# 0    41                                                                                                                                                                       [end, user, preferences, retrieval, video, data, database, based, arrangements, recognizing, users, profiles, network, switching, protocols, processing, wireless, networks]
# 0    42                                                                                                                                                                                                                                                                [environmental, sensors, detecting, temperature, luminosity, pressure, earthquakes]
# 0    43                                                                                                                                                                                                                                                                                                                 [sound, input, device, microphone]
# 0    44                                                                                                                                                                                                                                                                                                                       [cameras, takes, precedence]
# 0    45                                        [detecting, physical, presence, behaviour, user, using, sensors, detect, leaving, room, changes, face, expression, tv, program, methods, arrangements, recognising, human, body, animal, bodies, parts, acquiring, faces, facial, sketches, expressions, movements, identifying, users, broadcast, systems]
# 0    46                                                                                                                                                                                                                                                                                 [control, parameters, trick, play, commands, viewpoint, selection]
# 0    47                                                                                                                                                                                                                                                                                      [buckets, discharging, overhead, container, mounted, machine]
# 0    48                                                                                                                                                                                                            [component, parts, dredgers, soil, shifting, machines, restricted, kinds, covered, groups, laying, devices, trailing, electric, cables]
# 0    49                                                                                                                                                                                                                                                                                                                                    [moving, rails]
# 0    50                                                                                                                                                                                                                                             [improving, mounting, assembling, frame, elements, disposition, components, superstructures, specific]
# 0    51                                                                                                                                                                                                                                                                                                                     [using, gettering, substances]
# 0    52                                                                                                                                                                                                                                                                                         [characterised, drive, mechanism, valves, membrane, index]
# 0    53                                                                                                                                                                                                                                                                                                    [characterised, features, meter, body, housing]
# 0    54                                                                                                                                                                                                                                                                                                           [symmetrical, generally, shaped, clamps]
# 0    55                                                                                                                                                                                                                                                     [sensing, data, fields, affixed, objects, articles, coded, labels, postal, sorting, conveying]
# 0    56                                                                                                                                                                                                                                                                                 [printed, characters, having, additional, code, marks, containing]
# 0    57                                                                                                                                                                                                                                                                                                                 [automatic, carbide, feed, valves]

# %%
corrected_df.to_csv('corrected_test.csv')
